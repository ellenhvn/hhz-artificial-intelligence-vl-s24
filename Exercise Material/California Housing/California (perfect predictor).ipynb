# %% [markdown]
# # California Housing with Tax (Example "perfect predictor")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
import seaborn as sns
sns.set()

# %%
# Run this cell if you are working on Cloud Pak For Data
# Fetch the file
my_file = project.get_file("housing-with-tax.csv")

# Read the CSV data file from the object storage into a pandas DataFrame
my_file.seek(0)
original_data = pd.read_csv(my_file)

original_data.head()

# %%
# Run this cell if you are working locally 
original_data = pd.read_csv('housing-with-tax.csv')

# %%
data_wo_null = original_data.dropna(axis=0)
data_wo_null.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# median_tax            0
# dtype: int64

# %%
data_reduced_features = data_wo_null[['housing_median_age', 'total_rooms','population', 'median_income', 'median_house_value','ocean_proximity', 'median_tax']]
data_reduced_features.head()
# Out:
#    housing_median_age  total_rooms  population  median_income  \
# 0                  41          880         322         8.3252
# 1                  21         7099        2401         8.3014
# 2                  52         1467         496         7.2574
# 3                  52         1274         558         5.6431
# 4                  52         1627         565         3.8462
#
#    median_house_value ocean_proximity  median_tax
# 0              452600        NEAR BAY     85994.0
# 1              358500        NEAR BAY     68115.0
# 2              352100        NEAR BAY     66899.0
# 3              341300        NEAR BAY     64847.0
# 4              342200        NEAR BAY     65018.0

# %%
df_dummies = pd.get_dummies(data_reduced_features, drop_first=True) # 0-1 encoding for categorical values
df_dummies.head()
# Out:
#    housing_median_age  total_rooms  population  median_income  \
# 0                  41          880         322         8.3252
# 1                  21         7099        2401         8.3014
# 2                  52         1467         496         7.2574
# 3                  52         1274         558         5.6431
# 4                  52         1627         565         3.8462
#
#    median_house_value  median_tax  ocean_proximity_INLAND  \
# 0              452600     85994.0                   False
# 1              358500     68115.0                   False
# 2              352100     66899.0                   False
# 3              341300     64847.0                   False
# 4              342200     65018.0                   False
#
#    ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                      True
# 1                   False                      True
# 2                   False                      True
# 3                   False                      True
# 4                   False                      True
#
#    ocean_proximity_NEAR OCEAN
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %%
target = df_dummies['median_house_value'] # feature to be predicted
predictors = df_dummies.drop(['median_house_value'], axis = 1) # all other features are used as predictors

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.2, random_state=123) # 80-20 split into training and test data

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('training performance')
print(reg.score(X_train,y_train))
print('test performance')
print(reg.score(X_test,y_test))
# Out:
# training performance
# 1.0
# test performance
# 1.0

# %%
y_pred = reg.predict(X_test)
test = pd.DataFrame({'Predicted':y_pred,'Actual':y_test})
fig= plt.figure(figsize=(16,8))
test = test.reset_index()
test = test.drop(['index'],axis=1)
plt.plot(test[:50])
plt.legend(['Actual','Predicted'])
sns.jointplot(x='Actual',y='Predicted',data=test,kind='reg',);
# Out:
# /Users/ellenhoeven/opt/anaconda3/envs/hhz-py311/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ellenhoeven/opt/anaconda3/envs/hhz-py311/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ellenhoeven/opt/anaconda3/envs/hhz-py311/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ellenhoeven/opt/anaconda3/envs/hhz-py311/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/ellenhoeven/opt/anaconda3/envs/hhz-py311/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ellenhoeven/opt/anaconda3/envs/hhz-py311/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
